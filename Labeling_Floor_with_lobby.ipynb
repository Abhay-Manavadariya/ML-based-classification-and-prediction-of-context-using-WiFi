# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_excel('/content/LAB_DATA_G2.xlsx')
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0         Location            SSID   AP01   AP02  \
# 0             0           0   LAB_0_12PM_A_1  DAIICT_Student -100.0 -100.0
# 1             1           1   LAB_0_12PM_A_1       DA_Public  -52.0  -68.0
# 2             2           2  LAB_0_12PM_A_10  DAIICT_Student -100.0 -100.0
# 3             3           3  LAB_0_12PM_A_10       DA_Public -100.0 -100.0
# 4             4           4  LAB_0_12PM_A_11  DAIICT_Student -100.0 -100.0
#
#     AP03   AP04   AP05   AP06  ...  AP45  AP46  AP47  AP48  AP49  AP50  AP51  \
# 0 -100.0 -100.0 -100.0 -100.0  ...  -100  -100  -100  -100  -100  -100  -100
# 1  -79.2 -100.0  -83.0 -100.0  ...  -100  -100  -100  -100  -100  -100  -100
# 2 -100.0 -100.0 -100.0 -100.0  ...  -100  -100  -100  -100  -100  -100  -100
# 3  -85.0 -100.0 -100.0  -85.0  ...  -100  -100  -100  -100  -100  -100  -100
# 4 -100.0 -100.0 -100.0 -100.0  ...  -100  -100  -100  -100  -100  -100  -100
#
#    AP52  AP53  AP54
# 0  -100  -100  -100
# ...

# %%
df=df.iloc[:,2:]

# %%
df.head()
# Out:
#           Location            SSID   AP01   AP02   AP03   AP04   AP05   AP06  \
# 0   LAB_0_12PM_A_1  DAIICT_Student -100.0 -100.0 -100.0 -100.0 -100.0 -100.0
# 1   LAB_0_12PM_A_1       DA_Public  -52.0  -68.0  -79.2 -100.0  -83.0 -100.0
# 2  LAB_0_12PM_A_10  DAIICT_Student -100.0 -100.0 -100.0 -100.0 -100.0 -100.0
# 3  LAB_0_12PM_A_10       DA_Public -100.0 -100.0  -85.0 -100.0 -100.0  -85.0
# 4  LAB_0_12PM_A_11  DAIICT_Student -100.0 -100.0 -100.0 -100.0 -100.0 -100.0
#
#     AP07   AP08  ...  AP45  AP46  AP47  AP48  AP49  AP50  AP51  AP52  AP53  \
# 0  -52.0  -68.0  ...  -100  -100  -100  -100  -100  -100  -100  -100  -100
# 1 -100.0 -100.0  ...  -100  -100  -100  -100  -100  -100  -100  -100  -100
# 2  -75.0 -100.0  ...  -100  -100  -100  -100  -100  -100  -100  -100  -100
# 3 -100.0 -100.0  ...  -100  -100  -100  -100  -100  -100  -100  -100  -100
# 4 -100.0 -100.0  ...  -100  -100  -100  -100  -100  -100  -100  -100  -100
#
#    AP54
# 0  -100
# 1  -100
# 2  -100
# 3  -100
# ...

# %%
def assign_label(location):
    match = re.match(r"LAB_(\d)_.*?([A-Z]+)_(\d+)", location)
    if match:
        floor, section, number = match.groups()
        floor = int(floor)
        number = int(number)

        # Lobbies A_1 to A_12, B_1 to B_12
        if section in {"A", "B"} and 1 <= number <= 12:
            return floor

        # Rooms C_1 and C_2 to O_1 and O_2
        if section in {"C", "D", "E", "F", "G", "H", "I", "J", "K", "L", "M", "N", "O"} and 1 <= number <= 2:
            return floor + 3

        # Rooms P_1 to P_12 and Q_1 to Q_12
        if section in {"P", "Q"} and 1 <= number <= 12:
            return floor + 6

        # Rooms C_13, C_14 to O_13, O_14
        if section in {"C", "D", "E", "F", "G", "H", "I", "J", "K", "L", "M", "N", "O"} and 13 <= number <= 14:
            return floor + 9

    return None

# Apply the function to the Location column to create a new 'Label' column
df['Label'] = df['Location'].apply(assign_label).astype('Int64')

# %%
df.head()
# Out:
#           Location            SSID   AP01   AP02   AP03   AP04   AP05   AP06  \
# 0   LAB_0_12PM_A_1  DAIICT_Student -100.0 -100.0 -100.0 -100.0 -100.0 -100.0
# 1   LAB_0_12PM_A_1       DA_Public  -52.0  -68.0  -79.2 -100.0  -83.0 -100.0
# 2  LAB_0_12PM_A_10  DAIICT_Student -100.0 -100.0 -100.0 -100.0 -100.0 -100.0
# 3  LAB_0_12PM_A_10       DA_Public -100.0 -100.0  -85.0 -100.0 -100.0  -85.0
# 4  LAB_0_12PM_A_11  DAIICT_Student -100.0 -100.0 -100.0 -100.0 -100.0 -100.0
#
#     AP07   AP08  ...  AP46  AP47  AP48  AP49  AP50  AP51  AP52  AP53  AP54  \
# 0  -52.0  -68.0  ...  -100  -100  -100  -100  -100  -100  -100  -100  -100
# 1 -100.0 -100.0  ...  -100  -100  -100  -100  -100  -100  -100  -100  -100
# 2  -75.0 -100.0  ...  -100  -100  -100  -100  -100  -100  -100  -100  -100
# 3 -100.0 -100.0  ...  -100  -100  -100  -100  -100  -100  -100  -100  -100
# 4 -100.0 -100.0  ...  -100  -100  -100  -100  -100  -100  -100  -100  -100
#
#    Label
# 0      0
# 1      0
# 2      0
# ...

# %%
df['Label'].value_counts()
# Out:
# Label
# 3     208
# 9     208
# 10    208
# 5     208
# 11    208
# 4     204
# 0     192
# 6     192
# 1     192
# 8     192
# 2     168
# 7     144
# Name: count, dtype: Int64

# %%
df.to_csv('G2_final_data_With_floor_and_lobby.csv',index=False)
